# %% [markdown]
# ## Marketing Analytics Project
# ### Meetup.com Recommendation Systems
# ### Implicit Recommendation using Matrix Factorization using ALS (RSVP)

# %%
import sys
import pandas as pd
import numpy as np
import scipy.sparse as sparse
from scipy.sparse.linalg import spsolve
from sklearn.preprocessing import MinMaxScaler
import random
import implicit

# %%
## Set the pandas dataframes to display a fixed number of columns and rows
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)

# %% [markdown]
# ### Data loading and preprocessing

# %%
## load the RSVP, Member and Events data 
rsvp = pd.read_csv('rsvps_all_new.csv')
members = pd.read_csv('members_new.csv',encoding='latin-1')
events = pd.read_csv('events_all_new.csv',encoding='latin-1')
groups = pd.read_csv('groups_austin.csv',encoding='latin-1')

# %%
members[members['id'] == 285533436]
# Out:
#          Unnamed: 0  Unnamed: 0.1  bio    city country  group_id hometown  \
# 161508         1293          1293  NaN  Austin      us  14364582      NaN
# 555350          829           829  NaN  Austin      us  18746019      NaN
# 902864          196           196  NaN  Austin      us  27072136      NaN
# 926458          961           961  NaN  Austin      us  27919387      NaN
# 951078          436           436  NaN  Austin      us  29004437      NaN
# 1016126         431           431  NaN  Austin      us  31158184      NaN
# 1060173          42            42  NaN  Austin      us  32750265      NaN
# 1170769        1390          1390  NaN  Austin      us   5051822      NaN
# 1192716        1001          1001  NaN  Austin      us   5947662      NaN
#
#                   id        joined lang    lat  \
# 161508   285533436.0  1.568349e+12  NaN  30.22
# 555350   285533436.0  1.564625e+12  NaN  30.22
# 902864   285533436.0  1.570405e+12  NaN  30.22
# 926458   285533436.0  1.569079e+12  NaN  30.22
# 951078   285533436.0  1.563543e+12  NaN  30.22
# 1016126  285533436.0  1.563563e+12  NaN  30.22
# 1060173  285533436.0  1.570452e+12  NaN  30.22
# 1170769  285533436.0  1.568260e+12  NaN  30.22
# 1192716  285533436.0  1.568491e+12  NaN  30.22
#
#                                             link    lon          name  \
# 161508   http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 555350   http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 902864   http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 926458   http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 951078   http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 1016126  http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 1060173  http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 1170769  http://www.meetup.com/members/285533436 -97.75  Rachel Meade
# 1192716  http://www.meetup.com/members/285533436 -97.75  Rachel Meade
#
#         other_services.facebook.identifier other_services.flickr.identifier  \
# 161508                                 NaN                              NaN
# 555350                                 NaN                              NaN
# 902864                                 NaN                              NaN
# 926458                                 NaN                              NaN
# 951078                                 NaN                              NaN
# 1016126                                NaN                              NaN
# 1060173                                NaN                              NaN
# 1170769                                NaN                              NaN
# 1192716                                NaN                              NaN
#
#         other_services.linkedin.identifier other_services.tumblr.identifier  \
# 161508                                 NaN                              NaN
# 555350                                 NaN                              NaN
# 902864                                 NaN                              NaN
# 926458                                 NaN                              NaN
# 951078                                 NaN                              NaN
# 1016126                                NaN                              NaN
# 1060173                                NaN                              NaN
# 1170769                                NaN                              NaN
# 1192716                                NaN                              NaN
#
#         other_services.twitter.identifier                   photo.base_url  \
# 161508                                NaN  https://secure.meetupstatic.com
# 555350                                NaN  https://secure.meetupstatic.com
# 902864                                NaN  https://secure.meetupstatic.com
# 926458                                NaN  https://secure.meetupstatic.com
# 951078                                NaN  https://secure.meetupstatic.com
# 1016126                               NaN  https://secure.meetupstatic.com
# 1060173                               NaN  https://secure.meetupstatic.com
# 1170769                               NaN  https://secure.meetupstatic.com
# 1192716                               NaN  https://secure.meetupstatic.com
#
#                                         photo.highres_link  photo.photo_id  \
# 161508   https://secure.meetupstatic.com/photos/member/...     290878293.0
# 555350   https://secure.meetupstatic.com/photos/member/...     290878293.0
# 902864   https://secure.meetupstatic.com/photos/member/...     290878293.0
# 926458   https://secure.meetupstatic.com/photos/member/...     290878293.0
# 951078   https://secure.meetupstatic.com/photos/member/...     290878293.0
# 1016126  https://secure.meetupstatic.com/photos/member/...     290878293.0
# 1060173  https://secure.meetupstatic.com/photos/member/...     290878293.0
# 1170769  https://secure.meetupstatic.com/photos/member/...     290878293.0
# 1192716  https://secure.meetupstatic.com/photos/member/...     290878293.0
#
#                                           photo.photo_link  \
# 161508   https://secure.meetupstatic.com/photos/member/...
# 555350   https://secure.meetupstatic.com/photos/member/...
# 902864   https://secure.meetupstatic.com/photos/member/...
# 926458   https://secure.meetupstatic.com/photos/member/...
# 951078   https://secure.meetupstatic.com/photos/member/...
# 1016126  https://secure.meetupstatic.com/photos/member/...
# 1060173  https://secure.meetupstatic.com/photos/member/...
# 1170769  https://secure.meetupstatic.com/photos/member/...
# 1192716  https://secure.meetupstatic.com/photos/member/...
#
#                                           photo.thumb_link photo.type state  \
# 161508   https://secure.meetupstatic.com/photos/member/...     member    TX
# 555350   https://secure.meetupstatic.com/photos/member/...     member    TX
# 902864   https://secure.meetupstatic.com/photos/member/...     member    TX
# 926458   https://secure.meetupstatic.com/photos/member/...     member    TX
# 951078   https://secure.meetupstatic.com/photos/member/...     member    TX
# 1016126  https://secure.meetupstatic.com/photos/member/...     member    TX
# 1060173  https://secure.meetupstatic.com/photos/member/...     member    TX
# 1170769  https://secure.meetupstatic.com/photos/member/...     member    TX
# 1192716  https://secure.meetupstatic.com/photos/member/...     member    TX
#
#          status topics       visited
# 161508   active     []  1.571974e+12
# 555350   active     []  1.570672e+12
# 902864   active     []  1.570672e+12
# 926458   active     []  1.570672e+12
# 951078   active     []  1.570672e+12
# 1016126  active     []  1.571974e+12
# 1060173  active     []  1.571867e+12
# 1170769  active     []  1.570672e+12
# 1192716  active     []  1.570672e+12

# %%
groups[groups['id'] == 5947662].name
# Out:
# 2141    PyLadies ATX
# Name: name, dtype: object

# %% [markdown]
# #### Extract the required columns from the members dataframe

# %%
members = members[['group_id','id','name','joined','visited','topics']]
members['id'] = members['id'].astype(int)
members.head()
# Out:
#    group_id         id              name        joined       visited  \
# 0     10023  179008112               ...  1.492474e+12  1.492474e+12
# 1     10023    4099389  *!* Tonya P. *!*  1.552514e+12  1.563500e+12
# 2     10023    7436497   ** Marcia S. **  1.213335e+12  1.213853e+12
# 3     10023  291431587     1Barret1WemTD  1.570863e+12  1.571010e+12
# 4     10023  179208612                 A  1.414026e+12  1.426009e+12
#
#                                               topics
# 0                                                 []
# 1  [{'urlkey': 'ballroomdance', 'name': 'Ballroom...
# 2                                                 []
# 3                                                 []
# 4                                                 []

# %% [markdown]
# #### Extract the required columns from the groups, events and rsvp dataframes

# %%
groups = groups[['category.id','description','id','members','name','rating','topics','urlname','who']]
events = events[['group.id','group.urlname','group.name','group.who','id']]
rsvp = rsvp[['event.id','group.id','member.member_id','response','rsvp_id']]

# %% [markdown]
# ####  Calculate the number of events organized by each group

# %%
group_events = pd.DataFrame(events.groupby('group.id')["id"].nunique()).reset_index()
group_events = group_events.rename(columns = {'id':'count_of_events'})

# %% [markdown]
# #### Calculate the number of RSVPs for each member per group

# %%
rsvp_data = pd.DataFrame(rsvp.groupby(['group.id','member.member_id'])['rsvp_id'].count())
rsvp_data = rsvp_data.reset_index().rename(columns = {'rsvp_id':'count_of_rsvps'})

# %% [markdown]
# #### Merge the event count and RSVP information with the members dataframe

# %%
## Merge members and rsvp_data on member_id and group_id to get the RSVP information for each member and group.
members_rsvp = members.merge(rsvp_data, left_on =['group_id','id'],right_on=['group.id','member.member_id'], how='left')
members_rsvp = members_rsvp[['name','group_id',"id","count_of_rsvps"]]

## Merge the new dataset with group_events to get the number of events organized by each group
members_rsvp = members_rsvp.merge(group_events, left_on ='group_id', right_on ='group.id')

## Fill the NA values with 0 
members_rsvp["count_of_rsvps"].fillna(0, inplace=True)
members_rsvp["count_of_events"].fillna(0, inplace=True)

# %% [markdown]
# #### Calculate the number of events of a group that a member has RSVP'd for by the total number of events organized by the group

# %%
members_rsvp["rsvp_for_events"] = members_rsvp["count_of_rsvps"]/members_rsvp["count_of_events"]
members_rsvp = members_rsvp[["group_id","id","rsvp_for_events",'name']]
members_rsvp["rsvp_for_events"].fillna(0, inplace=True)

# %%
## Scale this ratio to be between 1 and 10
members_rsvp['rsvp_total'] = 1 + (members_rsvp['rsvp_for_events']-members_rsvp['rsvp_for_events'].min())*(10-1)/(members_rsvp['rsvp_for_events'].max()-members_rsvp['rsvp_for_events'].min())

# %%
## Select the required columns for recommendation
members_rsvp.columns = ['group_id', 'member_id', 'rsvp_for_events', 'member_name', 'rsvp_total']

# %%
members_rsvp.head()
# Out:
#    group_id  member_id  rsvp_for_events       member_name  rsvp_total
# 0     10023  179008112              0.0               ...         1.0
# 1     10023    4099389              0.0  *!* Tonya P. *!*         1.0
# 2     10023    7436497              0.0   ** Marcia S. **         1.0
# 3     10023  291431587              0.0     1Barret1WemTD         1.0
# 4     10023  179208612              0.0                 A         1.0

# %%
## Create a copy of the main dataframe to pass it to the recommendation system
main_data = members_rsvp
data = main_data.dropna()
data = data.copy()

# %% [markdown]
# #### Convert the member and group IDs to category codes

# %%
## Converting the numbers to categories to be used for creating the categorical codes to avoid using long hash keys 
data['member_id'] = data['member_id'].astype('category')
data['group_id'] = data['group_id'].astype('category')

## cat.codes creates a categorical id for the users and artists
data['user_id'] = data['member_id'].cat.codes
data['grp_id'] = data['group_id'].cat.codes

# %% [markdown]
# #### Convert the data to item-user and user-item matrices
# The implicit library expects data as a item-user matrix so we create two matrices, one for fitting the model (item-user) and one for recommendations (user-item)

# %%
sparse_item_user = sparse.csr_matrix((data['rsvp_total'].astype(float), (data['grp_id'], data['user_id'])))
sparse_user_item = sparse.csr_matrix((data['rsvp_total'].astype(float), (data['user_id'], data['grp_id'])))

# %%
## Display the sparsity
matrix_size = sparse_user_item.shape[0]*sparse_user_item.shape[1] # Number of possible interactions in the matrix
num_members = len(sparse_user_item.nonzero()[0]) # Number of items interacted with
sparsity = 100*(1 - (num_members/matrix_size))
print("The sparsity of the dataset is",sparsity)
# Out:
# The sparsity of the dataset is 99.60808109549494

# %% [markdown]
# ### Train-Test split
#
# ![image.png](attachment:image.png)

# %%
def make_train(ratings, pct_test = 0.2):
    '''
    This function will take in the original user-item matrix and "mask" a percentage of the original ratings where a
    user-item interaction has taken place for use as a test set. The test set will contain all of the original ratings, 
    while the training set replaces the specified percentage of them with a zero in the original ratings matrix. 
    
    parameters: 
    
    ratings - the original ratings matrix from which you want to generate a train/test set. Test is just a complete
    copy of the original set. This is in the form of a sparse csr_matrix. 
    
    pct_test - The percentage of user-item interactions where an interaction took place that you want to mask in the 
    training set for later comparison to the test set, which contains all of the original ratings. 
    
    returns:
    
    training_set - The altered version of the original data with a certain percentage of the user-item pairs 
    that originally had interaction set back to zero.
    
    test_set - A copy of the original ratings matrix, unaltered, so it can be used to see how the rank order 
    compares with the actual interactions.
    
    user_inds - From the randomly selected user-item indices, which user rows were altered in the training data.
    This will be necessary later when evaluating the performance via AUC.
    '''
    test_set = ratings.copy() # Make a copy of the original set to be the test set. 
    test_set[test_set != 0] = 1 # Store the test set as a binary preference matrix
    
    training_set = ratings.copy() # Make a copy of the original data we can alter as our training set. 
    
    nonzero_inds = training_set.nonzero() # Find the indices in the ratings data where an interaction exists
    nonzero_pairs = list(zip(nonzero_inds[0], nonzero_inds[1])) # Zip these pairs together of item,user index into list

    
    random.seed(0) # Set the random seed to zero for reproducibility
    
    num_samples = int(np.ceil(pct_test*len(nonzero_pairs))) # Round the number of samples needed to the nearest integer
    samples = random.sample(nonzero_pairs, num_samples) # Sample a random number of item-user pairs without replacement

    item_inds = [index[0] for index in samples] # Get the item row indices

    user_inds = [index[1] for index in samples] # Get the user column indices

    
    training_set[item_inds, user_inds] = 0 # Assign all of the randomly chosen user-item pairs to zero
    training_set.eliminate_zeros() # Get rid of zeros in sparse array storage after update to save space
    mask = {}
    #reference dictionary
    
    return training_set, test_set, list(set(user_inds)) # Output the unique list of user columns that were altered

# %%
## 20% of the data has been masked for this exercise
product_train, product_test, product_users_altered = make_train(sparse_item_user, pct_test = 0.2)

# %% [markdown]
# ### Alternating Least Squares

# %% [markdown]
# With the ALS model, we can use a grid search to find the optimal hyperparameters. This was implemented on PySpark.
# The grid search gave us the best model with 20 latent factors and regularization = 0.1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Initialize the ALS model and fit it using the sparse item-user matrix
# Parameters that we have chosen
# 1. factors = 20 -- Latent factors for user and item vectors
# 2. iterations = 20 -- Number of iterations to use while fitting the data
# 3. regularization = 0.1 -- regularization constant to be used in the cost function

model = implicit.als.AlternatingLeastSquares(factors=20, regularization=0.1, iterations=40)

# Calculate the confidence by multiplying it by our alpha value.(alpha value corresponds to the confidence metric 
# that we discussed earlier)

alpha_val = 15
data_conf = (product_train * alpha_val).astype('double')

# We have used an alpha_val of 15 after performing some iterations with different alpha values
#Fit the model
model.fit(data_conf)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 40.0/40 [00:19<00:00,  2.08it/s]

# %%
## Latent factor matrix
item_vecs = model.item_factors
user_vecs = model.user_factors

print('Shape of group vector matrix : ', item_vecs.shape)
print('Shape of member vector matrix : ', user_vecs.shape)
# Out:
# Shape of group vector matrix :  (816, 20)
# Shape of member vector matrix :  (232987, 20)

# %% [markdown]
# #### Calculate the AUC scores to evaluate the recommender system

# %%
from sklearn import metrics
import matplotlib.pylab as plt
def auc_score(predictions, test):
    '''
    This simple function will output the area under the curve using sklearn's metrics. 
    
    parameters:
    
    - predictions: your prediction output
    
    - test: the actual target result you are comparing to
    
    returns:
    
    - AUC (area under the Receiver Operating Characterisic curve)
    '''
    fpr, tpr, thresholds = metrics.roc_curve(test, predictions)
    return metrics.auc(fpr, tpr)

def calc_mean_auc(training_set, altered_users, predictions, test_set):
    '''
    This function will calculate the mean AUC by user for any user that had their user-item matrix altered. 
    
    parameters:
    
    training_set - The training set resulting from make_train, where a certain percentage of the original
    user/item interactions are reset to zero to hide them from the model 
    
    predictions - The matrix of your predicted ratings for each user/item pair as output from the implicit MF.
    These should be stored in a list, with user vectors as item zero and item vectors as item one. 
    
    altered_users - The indices of the users where at least one user/item pair was altered from make_train function
    
    test_set - The test set constucted earlier from make_train function
    
    
    returns:
    
    The mean AUC (area under the Receiver Operator Characteristic curve) of the test set only on user-item interactions
    there were originally zero to test ranking ability in addition to the most popular items as a benchmark.
    '''
    
    store_auc = [] # An empty list to store the AUC for each user that had an item removed from the training set
    popularity_auc = [] # To store popular AUC scores
    pop_items = np.array(test_set.sum(axis = 1)).reshape(-1) # Get sum of item iteractions to find most popular
    item_vecs = predictions[1]
    for user in altered_users: # Iterate through each user that had an item altered
        training_column = training_set[:,user].toarray().reshape(-1) # Get the training set column
        zero_inds = np.where(training_column == 0) # Find where the interaction had not yet occurred
        
        # Get the predicted values based on our user/item vectors
        user_vec = predictions[0][user,:]
        pred = user_vec.dot(item_vecs).toarray()[0,zero_inds].reshape(-1)
        
        # Get only the items that were originally zero
        # Select all ratings from the MF prediction for this user that originally had no iteraction
        actual = test_set[:,user].toarray()[zero_inds,0].reshape(-1)
        
        # Select the binarized yes/no interaction pairs from the original full data
        # that align with the same pairs in training 
        pop = pop_items[zero_inds] # Get the item popularity for our chosen items
        
        store_auc.append(auc_score(pred, actual)) # Calculate AUC for the given user and store
        
        popularity_auc.append(auc_score(pop, actual)) # Calculate AUC using most popular and score
    # End users iteration
    
    return float('%.3f'%np.mean(store_auc)), float('%.3f'%np.mean(popularity_auc))  
   # Return the mean AUC rounded to three decimal places for both test and popularity benchmark

# %%
## AUC score for our recommender system
calc_mean_auc(product_train, product_users_altered,
              [sparse.csr_matrix(user_vecs), sparse.csr_matrix(item_vecs.T)], product_test)
# Out:
# (0.761, 0.837)

# %% [markdown]
# #### Create a dictionary for the member and group IDs to be mapped to their respective category codes

# %%
mapping_group_dict = pd.Series(data['grp_id'].values,index=data.group_id).to_dict()
mapping_member_dict = pd.Series(data['user_id'].values,index=data.member_id).to_dict()

# %%
## Example User
## mapping_member_dict[109081562]

# %%
events.head()
# Out:
#    group.id  group.urlname                             group.name  \
# 0   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 1   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 2   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 3   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 4   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
#
#         group.who             id
# 0  Early adopters   vjnqbryzpbhb
# 1  Early adopters   vjnqbryzqbfb
# 2  Early adopters  vjnqbrybccbkb
# 3  Early adopters  vjnqbrybcdbgb
# 4  Early adopters  vjnqbrybcfbfb

# %%
events.columns = ['group_id', 'group.urlname', 'group.name', 'group.who' ,'id']

# %%
events.head()
# Out:
#    group_id  group.urlname                             group.name  \
# 0   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 1   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 2   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 3   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
# 4   8052752  BitcoinAustin  Austin Bitcoin Meetup: Satoshi Vision
#
#         group.who             id
# 0  Early adopters   vjnqbryzpbhb
# 1  Early adopters   vjnqbryzqbfb
# 2  Early adopters  vjnqbrybccbkb
# 3  Early adopters  vjnqbrybcdbgb
# 4  Early adopters  vjnqbrybcfbfb

# %%
## Merge the data with the events dataframe to get the group names
data_final = pd.merge(data, events[['group.name','group_id']], on = 'group_id', how = 'inner')
data_final = data_final.drop_duplicates()

# %%
data_final.head()
# Out:
#     group_id  member_id  rsvp_for_events       member_name  rsvp_total  \
# 0      10023  179008112              0.0               ...         1.0
# 12     10023    4099389              0.0  *!* Tonya P. *!*         1.0
# 24     10023    7436497              0.0   ** Marcia S. **         1.0
# 36     10023  291431587              0.0     1Barret1WemTD         1.0
# 48     10023  179208612              0.0                 A         1.0
#
#     user_id  grp_id                   group.name
# 0     92258       0  Love-A-Bull Pit Bull Meetup
# 12     3776       0  Love-A-Bull Pit Bull Meetup
# 24     8434       0  Love-A-Bull Pit Bull Meetup
# 36   230614       0  Love-A-Bull Pit Bull Meetup
# 48    92331       0  Love-A-Bull Pit Bull Meetup

# %%
## Testing
## Pick a user from the Austin Data Science group
data_final[data_final['group.name'] == 'Data on Tap'].sort_values(by = "member_name", ascending = False)
# Out:
#           group_id  member_id  rsvp_for_events  \
# 36721093  31158184  282484228              0.0
# 36721076  31158184    7784331              0.0
# 36721070  31158184   18142841              0.0
# 36721055  31158184    9172391              0.0
# 36721039  31158184  188796527              0.0
# 36720854  31158184  284069460              0.0
# 36720848  31158184  284970529              0.0
# 36720846  31158184  215863630              0.0
# 36720820  31158184   10745974              0.0
# 36720816  31158184  183747513              0.0
# 36720807  31158184    6755762              0.0
# 36720780  31158184  134137472              0.0
# 36720751  31158184    8988433              0.0
# 36720750  31158184  187545323              0.0
# 36720690  31158184  284862068              0.0
# 36720639  31158184  279189482              0.0
# 36720637  31158184  286888330              0.0
# 36720577                    Alec Bunnell         1.0   225688     648
# 36720575                Akshay Chaudhari         1.0   230918     648
# 36720573              Aishwarya Sudhakar         5.5   228335     648
# 36720572                 Aishwarya Pawar         1.0   226822     648
# 36720571                   Adrian Campos         1.0   184819     648
# 36720570              Aditya Ratnaparkhi         1.0   209351     648
# 36720569                         Addison         1.0   226287     648
# 36720568                    Adam William         1.0   228997     648
# 36720567                  Adam Kirschner         1.0   161740     648
# 36720566                      ActionSpot         1.0   152833     648
# 36720565                 Abhishek Kardak         1.0   104109     648
# 36720562                      Aaron Yang         1.0    94236     648
# 36720561                   Aaron Wiseman         1.0   229464     648
# 36720615                   ARNAV DESHWAL         1.0   227331     648
# 36720576                              AL         1.0   163835     648
# 36720574                              AJ         1.0    97653     648
# 36720563                              AB         1.0   120409     648
# 36720559                 A Meetup Member         1.0   117361     648
#
#            group.name
# 36721093  Data on Tap
# 36721076  Data on Tap
# 36721070  Data on Tap
# 36721055  Data on Tap
# 36721039  Data on Tap
# 36720854  Data on Tap
# 36720848  Data on Tap
# 36720846  Data on Tap
# 36720820  Data on Tap
# 36720816  Data on Tap
# 36720807  Data on Tap
# 36720780  Data on Tap
# 36720751  Data on Tap
# 36720750  Data on Tap
# 36720690  Data on Tap
# 36720639  Data on Tap
# 36720637  Data on Tap
# 36720630  Data on Tap
# 36720599  Data on Tap
# 36720564  Data on Tap
# 36720560  Data on Tap
# 36721127  Data on Tap
# 36721126  Data on Tap
# 36721125  Data on Tap
# 36721124  Data on Tap
# 36721123  Data on Tap
# 36721122  Data on Tap
# 36721120  Data on Tap
# 36721119  Data on Tap
# 36721118  Data on Tap
# 36721117  Data on Tap
# 36721116  Data on Tap
# 36721115  Data on Tap
# 36721114  Data on Tap
# 36721121  Data on Tap
# 36721113  Data on Tap
# 36721112  Data on Tap
# 36721111  Data on Tap
# 36721110  Data on Tap
# 36721109  Data on Tap
# 36721108  Data on Tap
# 36721107  Data on Tap
# 36721106  Data on Tap
# 36721103  Data on Tap
# 36721104  Data on Tap
# 36721102  Data on Tap
# 36721101  Data on Tap
# 36721100  Data on Tap
# 36721098  Data on Tap
# 36721097  Data on Tap
# 36721096  Data on Tap
# 36721095  Data on Tap
# 36721094  Data on Tap
# 36721092  Data on Tap
# 36721091  Data on Tap
# 36721105  Data on Tap
# 36721099  Data on Tap
# 36721090  Data on Tap
# 36721089  Data on Tap
# 36721088  Data on Tap
# 36721087  Data on Tap
# 36721086  Data on Tap
# 36721085  Data on Tap
# 36721084  Data on Tap
# 36721083  Data on Tap
# 36721082  Data on Tap
# 36721081  Data on Tap
# 36721080  Data on Tap
# 36721079  Data on Tap
# 36721078  Data on Tap
# 36721077  Data on Tap
# 36721075  Data on Tap
# 36721074  Data on Tap
# 36721073  Data on Tap
# 36721072  Data on Tap
# 36721071  Data on Tap
# 36721069  Data on Tap
# 36721068  Data on Tap
# 36721067  Data on Tap
# 36721066  Data on Tap
# 36721065  Data on Tap
# 36721064  Data on Tap
# 36721063  Data on Tap
# 36721062  Data on Tap
# 36721061  Data on Tap
# 36721060  Data on Tap
# 36721059  Data on Tap
# 36721058  Data on Tap
# 36721057  Data on Tap
# 36721056  Data on Tap
# 36721054  Data on Tap
# 36721053  Data on Tap
# 36721051  Data on Tap
# 36721050  Data on Tap
# 36721049  Data on Tap
# 36721048  Data on Tap
# 36721047  Data on Tap
# 36721046  Data on Tap
# 36721045  Data on Tap
# 36721044  Data on Tap
# 36721043  Data on Tap
# 36721042  Data on Tap
# 36721041  Data on Tap
# 36721040  Data on Tap
# 36721038  Data on Tap
# 36721037  Data on Tap
# 36721036  Data on Tap
# 36721035  Data on Tap
# 36721034  Data on Tap
# 36721032  Data on Tap
# 36721033  Data on Tap
# 36721031  Data on Tap
# 36721030  Data on Tap
# 36721029  Data on Tap
# 36721028  Data on Tap
# 36721027  Data on Tap
# 36721026  Data on Tap
# 36721025  Data on Tap
# 36721024  Data on Tap
# 36721023  Data on Tap
# 36721022  Data on Tap
# 36721021  Data on Tap
# 36721020  Data on Tap
# 36721019  Data on Tap
# 36721018  Data on Tap
# 36721017  Data on Tap
# 36721016  Data on Tap
# 36721052  Data on Tap
# 36721015  Data on Tap
# 36721014  Data on Tap
# 36721013  Data on Tap
# 36721012  Data on Tap
# 36721011  Data on Tap
# 36721010  Data on Tap
# 36721009  Data on Tap
# 36721008  Data on Tap
# 36721007  Data on Tap
# 36721006  Data on Tap
# 36721005  Data on Tap
# 36721004  Data on Tap
# 36721003  Data on Tap
# 36721002  Data on Tap
# 36721001  Data on Tap
# 36721000  Data on Tap
# 36720999  Data on Tap
# 36720998  Data on Tap
# 36720997  Data on Tap
# 36720996  Data on Tap
# 36720995  Data on Tap
# 36720994  Data on Tap
# 36720992  Data on Tap
# 36720993  Data on Tap
# 36720991  Data on Tap
# 36720990  Data on Tap
# 36720989  Data on Tap
# 36720988  Data on Tap
# 36720987  Data on Tap
# 36720986  Data on Tap
# 36720985  Data on Tap
# 36720984  Data on Tap
# 36720982  Data on Tap
# 36720983  Data on Tap
# 36720981  Data on Tap
# 36720980  Data on Tap
# 36720979  Data on Tap
# 36720978  Data on Tap
# 36720977  Data on Tap
# 36720976  Data on Tap
# 36720975  Data on Tap
# 36720974  Data on Tap
# 36720973  Data on Tap
# 36720972  Data on Tap
# 36720971  Data on Tap
# 36720970  Data on Tap
# 36720969  Data on Tap
# 36720968  Data on Tap
# 36720967  Data on Tap
# 36720966  Data on Tap
# 36720965  Data on Tap
# 36720964  Data on Tap
# 36720963  Data on Tap
# 36720962  Data on Tap
# 36720961  Data on Tap
# 36720960  Data on Tap
# 36720959  Data on Tap
# 36720958  Data on Tap
# 36720957  Data on Tap
# 36720956  Data on Tap
# 36720955  Data on Tap
# 36720954  Data on Tap
# 36720953  Data on Tap
# 36720952  Data on Tap
# 36720951  Data on Tap
# 36720950  Data on Tap
# 36720949  Data on Tap
# 36720948  Data on Tap
# 36720947  Data on Tap
# 36720946  Data on Tap
# 36720945  Data on Tap
# 36720944  Data on Tap
# 36720943  Data on Tap
# 36720942  Data on Tap
# 36720941  Data on Tap
# 36720940  Data on Tap
# 36720939  Data on Tap
# 36720938  Data on Tap
# 36720937  Data on Tap
# 36720936  Data on Tap
# 36720935  Data on Tap
# 36720934  Data on Tap
# 36720933  Data on Tap
# 36720932  Data on Tap
# 36720931  Data on Tap
# 36720930  Data on Tap
# 36720929  Data on Tap
# 36720928  Data on Tap
# 36720927  Data on Tap
# 36720926  Data on Tap
# 36720925  Data on Tap
# 36720924  Data on Tap
# 36720923  Data on Tap
# 36720922  Data on Tap
# 36720921  Data on Tap
# 36720920  Data on Tap
# 36720918  Data on Tap
# 36720917  Data on Tap
# 36720916  Data on Tap
# 36720915  Data on Tap
# 36720914  Data on Tap
# 36720913  Data on Tap
# 36720912  Data on Tap
# 36720911  Data on Tap
# 36720910  Data on Tap
# 36720909  Data on Tap
# 36720908  Data on Tap
# 36720907  Data on Tap
# 36720906  Data on Tap
# 36720905  Data on Tap
# 36720904  Data on Tap
# 36720903  Data on Tap
# 36720902  Data on Tap
# 36720901  Data on Tap
# 36720900  Data on Tap
# 36720899  Data on Tap
# 36720898  Data on Tap
# 36720897  Data on Tap
# 36720896  Data on Tap
# 36720895  Data on Tap
# 36720894  Data on Tap
# 36720893  Data on Tap
# 36720919  Data on Tap
# 36720892  Data on Tap
# 36720891  Data on Tap
# 36720890  Data on Tap
# 36720889  Data on Tap
# 36720888  Data on Tap
# 36720887  Data on Tap
# 36720886  Data on Tap
# 36720885  Data on Tap
# 36720884  Data on Tap
# 36720883  Data on Tap
# 36720882  Data on Tap
# 36720881  Data on Tap
# 36720880  Data on Tap
# 36720879  Data on Tap
# 36720878  Data on Tap
# 36720877  Data on Tap
# 36720876  Data on Tap
# 36720875  Data on Tap
# 36720874  Data on Tap
# 36720873  Data on Tap
# 36720872  Data on Tap
# 36720871  Data on Tap
# 36720870  Data on Tap
# 36720869  Data on Tap
# 36720868  Data on Tap
# 36720867  Data on Tap
# 36720866  Data on Tap
# 36720865  Data on Tap
# 36720864  Data on Tap
# 36720863  Data on Tap
# 36720862  Data on Tap
# 36720861  Data on Tap
# 36720860  Data on Tap
# 36720859  Data on Tap
# 36720858  Data on Tap
# 36720857  Data on Tap
# 36720856  Data on Tap
# 36720855  Data on Tap
# 36720853  Data on Tap
# 36720852  Data on Tap
# 36720851  Data on Tap
# 36720850  Data on Tap
# 36720849  Data on Tap
# 36720847  Data on Tap
# 36720845  Data on Tap
# 36720844  Data on Tap
# 36720843  Data on Tap
# 36720842  Data on Tap
# 36720841  Data on Tap
# 36720840  Data on Tap
# 36720839  Data on Tap
# 36720838  Data on Tap
# 36720837  Data on Tap
# 36720836  Data on Tap
# 36720835  Data on Tap
# 36720834  Data on Tap
# 36720833  Data on Tap
# 36720832  Data on Tap
# 36720831  Data on Tap
# 36720830  Data on Tap
# 36720829  Data on Tap
# 36720828  Data on Tap
# 36720827  Data on Tap
# 36720826  Data on Tap
# 36720825  Data on Tap
# 36720824  Data on Tap
# 36720823  Data on Tap
# 36720822  Data on Tap
# 36720821  Data on Tap
# 36720819  Data on Tap
# 36720818  Data on Tap
# 36720817  Data on Tap
# 36720815  Data on Tap
# 36720814  Data on Tap
# 36720813  Data on Tap
# 36720812  Data on Tap
# 36720811  Data on Tap
# 36720810  Data on Tap
# 36720809  Data on Tap
# 36720808  Data on Tap
# 36720806  Data on Tap
# 36720805  Data on Tap
# 36720804  Data on Tap
# 36720803  Data on Tap
# 36720802  Data on Tap
# 36720801  Data on Tap
# 36720800  Data on Tap
# 36720799  Data on Tap
# 36720798  Data on Tap
# 36720797  Data on Tap
# 36720796  Data on Tap
# 36720795  Data on Tap
# 36720794  Data on Tap
# 36720793  Data on Tap
# 36720792  Data on Tap
# 36720791  Data on Tap
# 36720790  Data on Tap
# 36720789  Data on Tap
# 36720788  Data on Tap
# 36720787  Data on Tap
# 36720786  Data on Tap
# 36720785  Data on Tap
# 36720784  Data on Tap
# 36720783  Data on Tap
# 36720782  Data on Tap
# 36720781  Data on Tap
# 36720779  Data on Tap
# 36720778  Data on Tap
# 36720777  Data on Tap
# 36720776  Data on Tap
# 36720775  Data on Tap
# 36720774  Data on Tap
# 36720773  Data on Tap
# 36720772  Data on Tap
# 36720771  Data on Tap
# 36720770  Data on Tap
# 36720769  Data on Tap
# 36720768  Data on Tap
# 36720767  Data on Tap
# 36720766  Data on Tap
# 36720765  Data on Tap
# 36720764  Data on Tap
# 36720763  Data on Tap
# 36720762  Data on Tap
# 36720761  Data on Tap
# 36720760  Data on Tap
# 36720759  Data on Tap
# 36720758  Data on Tap
# 36720757  Data on Tap
# 36720756  Data on Tap
# 36720755  Data on Tap
# 36720754  Data on Tap
# 36720753  Data on Tap
# 36720752  Data on Tap
# 36720749  Data on Tap
# 36720748  Data on Tap
# 36720747  Data on Tap
# 36720746  Data on Tap
# 36720745  Data on Tap
# 36720744  Data on Tap
# 36720743  Data on Tap
# 36720742  Data on Tap
# 36720741  Data on Tap
# 36720740  Data on Tap
# 36720739  Data on Tap
# 36720738  Data on Tap
# 36720737  Data on Tap
# 36720736  Data on Tap
# 36720735  Data on Tap
# 36720734  Data on Tap
# 36720733  Data on Tap
# 36720732  Data on Tap
# 36720731  Data on Tap
# 36720730  Data on Tap
# 36720729  Data on Tap
# 36720728  Data on Tap
# 36720727  Data on Tap
# 36720726  Data on Tap
# 36720725  Data on Tap
# 36720724  Data on Tap
# 36720723  Data on Tap
# 36720722  Data on Tap
# 36720721  Data on Tap
# 36720720  Data on Tap
# 36720719  Data on Tap
# 36720718  Data on Tap
# 36720717  Data on Tap
# 36720716  Data on Tap
# 36720715  Data on Tap
# 36720714  Data on Tap
# 36720713  Data on Tap
# 36720712  Data on Tap
# 36720711  Data on Tap
# 36720710  Data on Tap
# 36720709  Data on Tap
# 36720708  Data on Tap
# 36720707  Data on Tap
# 36720706  Data on Tap
# 36720705  Data on Tap
# 36720704  Data on Tap
# 36720703  Data on Tap
# 36720702  Data on Tap
# 36720701  Data on Tap
# 36720700  Data on Tap
# 36720699  Data on Tap
# 36720698  Data on Tap
# 36720697  Data on Tap
# 36720696  Data on Tap
# 36720695  Data on Tap
# 36720694  Data on Tap
# 36720693  Data on Tap
# 36720692  Data on Tap
# 36720691  Data on Tap
# 36720689  Data on Tap
# 36720688  Data on Tap
# 36720687  Data on Tap
# 36720686  Data on Tap
# 36720685  Data on Tap
# 36720684  Data on Tap
# 36720683  Data on Tap
# 36720682  Data on Tap
# 36720681  Data on Tap
# 36720680  Data on Tap
# 36720679  Data on Tap
# 36720678  Data on Tap
# 36720677  Data on Tap
# 36720676  Data on Tap
# 36720675  Data on Tap
# 36720674  Data on Tap
# 36720673  Data on Tap
# 36720672  Data on Tap
# 36720671  Data on Tap
# 36720670  Data on Tap
# 36720669  Data on Tap
# 36720668  Data on Tap
# 36720667  Data on Tap
# 36720666  Data on Tap
# 36720665  Data on Tap
# 36720664  Data on Tap
# 36720663  Data on Tap
# 36720662  Data on Tap
# 36720661  Data on Tap
# 36720660  Data on Tap
# 36720659  Data on Tap
# 36720658  Data on Tap
# 36720657  Data on Tap
# 36720656  Data on Tap
# 36720655  Data on Tap
# 36720654  Data on Tap
# 36720653  Data on Tap
# 36720652  Data on Tap
# 36720651  Data on Tap
# 36720650  Data on Tap
# 36720649  Data on Tap
# 36720648  Data on Tap
# 36720647  Data on Tap
# 36720646  Data on Tap
# 36720645  Data on Tap
# 36720644  Data on Tap
# 36720643  Data on Tap
# 36720642  Data on Tap
# 36720641  Data on Tap
# 36720640  Data on Tap
# 36720638  Data on Tap
# 36720636  Data on Tap
# 36720635  Data on Tap
# 36720634  Data on Tap
# 36720633  Data on Tap
# 36720632  Data on Tap
# 36720631  Data on Tap
# 36720629  Data on Tap
# 36720628  Data on Tap
# 36720627  Data on Tap
# 36720626  Data on Tap
# 36720625  Data on Tap
# 36720624  Data on Tap
# 36720623  Data on Tap
# 36720622  Data on Tap
# 36720621  Data on Tap
# 36720620  Data on Tap
# 36720619  Data on Tap
# 36720618  Data on Tap
# 36720617  Data on Tap
# 36720616  Data on Tap
# 36720614  Data on Tap
# 36720613  Data on Tap
# 36720612  Data on Tap
# 36720611  Data on Tap
# 36720610  Data on Tap
# 36720609  Data on Tap
# 36720608  Data on Tap
# 36720607  Data on Tap
# 36720606  Data on Tap
# 36720605  Data on Tap
# 36720604  Data on Tap
# 36720603  Data on Tap
# 36720602  Data on Tap
# 36720601  Data on Tap
# 36720600  Data on Tap
# 36720598  Data on Tap
# 36720597  Data on Tap
# 36720596  Data on Tap
# 36720595  Data on Tap
# 36720594  Data on Tap
# 36720593  Data on Tap
# 36720592  Data on Tap
# 36720591  Data on Tap
# 36720590  Data on Tap
# 36720589  Data on Tap
# 36720588  Data on Tap
# 36720587  Data on Tap
# 36720586  Data on Tap
# 36720585  Data on Tap
# 36720584  Data on Tap
# 36720583  Data on Tap
# 36720582  Data on Tap
# 36720581  Data on Tap
# 36720580  Data on Tap
# 36720579  Data on Tap
# 36720578  Data on Tap
# 36720577  Data on Tap
# 36720575  Data on Tap
# 36720573  Data on Tap
# 36720572  Data on Tap
# 36720571  Data on Tap
# 36720570  Data on Tap
# 36720569  Data on Tap
# 36720568  Data on Tap
# 36720567  Data on Tap
# 36720566  Data on Tap
# 36720565  Data on Tap
# 36720562  Data on Tap
# 36720561  Data on Tap
# 36720615  Data on Tap
# 36720576  Data on Tap
# 36720574  Data on Tap
# 36720563  Data on Tap
# 36720559  Data on Tap

# %%
## Find the 10 most similar groups to Austin Data Science
group_id = 329
n_similar = 10 # Getting the top ten similar items

print ("------------Actual group-------------------")
print (data_final[data_final['grp_id'] == group_id]['group.name'].head(1))
print ("------------Similar groups-------------------")

# Use implicit to get similar items.
similar = model.similar_items(group_id, 5)
# Print the names of our most similar groups
for group in similar:
    idx, score = group
    print (data_final['group.name'].loc[data_final.grp_id == idx].iloc[0])
# Out:
# ------------Actual group-------------------
# 20876398    Austin Data Science
# Name: group.name, dtype: object
# ------------Similar groups-------------------
# Austin Data Science
# Austin Deep Learning
# Austin Big Data AI
# Austin AI Developers Group
# Healthcare Predictive Analytics

# %% [markdown]
# ### Generating recommendations

# %%
def recommend_group(user_id, num_of_recs):
    # Use the implicit recommender.
    recommended = model.recommend(mapping_member_dict[user_id], sparse_user_item,N = num_of_recs,filter_already_liked_items = False)
    
    meetup_groups = []
    scores = []
    
    ## Get the member names from IDs
    for item in recommended:
        idx, score = item
        meetup_groups.append(data_final['group.name'].loc[data_final.grp_id == idx].iloc[0])
        scores.append(score)
    
    # Create a dataframe of member names and scores
    recommendations = pd.DataFrame({'groups': meetup_groups, 'score': scores})
    user_past_groups = members_rsvp[members_rsvp["member_id"] == user_id]
    user_past_groups = user_past_groups[user_past_groups["rsvp_total"] > 1]
    user_past_groups = user_past_groups.merge(groups, left_on = "group_id", right_on = "id", how="left")

    return recommendations, user_past_groups[["group_id","name","rsvp_total"]]

# %%
recommended_groups, past_groups = recommend_group(187481513, 10)

# %%
recommended_groups, past_groups = recommend_group(14136557, 10)

# %%
recommended_groups, past_groups = recommend_group(192867271, 10)

# %%
recommended_groups, past_groups = recommend_group(6192675, 10)

# %%
recommended_groups, past_groups = recommend_group(285533436, 10)

# %%
print("The following groups are recommended to the user:")
print(recommended_groups)
# Out:
# The following groups are recommended to the user:
#                             groups     score
# 0              Austin Data Science  1.225418
# 1             Austin Deep Learning  1.074968
# 2         The Austin Python Meetup  0.994722
# 3               Austin Big Data AI  0.994088
# 4       Austin AI Developers Group  0.899631
# 5      Women in Data Science - ATX  0.852709
# 6                Austin Data Geeks  0.833679
# 7                      Data on Tap  0.754062
# 8                     PyLadies ATX  0.744719
# 9  Healthcare Predictive Analytics  0.728205

# %%
print("The user is already a part of the following groups:")
print(past_groups)
# Out:
# The user is already a part of the following groups:
#    group_id                name  rsvp_total
# 0  14364582  Austin Big Data AI         5.5
# 1  31158184         Data on Tap         5.5
